# %%
import os
import pandas as pd
import numpy as np
import multiprocessing
import tensorflow as tf

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'
    

RND_SEED = 0
GPU_ID = 0
USE_GPU = True

if tf.config.list_physical_devices('GPU') and USE_GPU:
    gpus = tf.config.list_physical_devices('GPU')
    gpu_name = gpus[0].name  # You may specify an index if using multiple GPUs
    print(f"Using GPU - {gpu_name}")
    device = '/GPU:0'
else:
    device = '/CPU:0'

with tf.device(device):
    pass

print(f"Using device {device}")

N_CPU_CORES = multiprocessing.cpu_count()

BASE_FOLDER = os.path.join(
    "..", "input", "tlvmc-parkinsons-freezing-gait-prediction"
)

print(f"Number of CPU cores available: {N_CPU_CORES}")

pd.set_option('display.max_columns', 30)
pd.set_option('display.max_rows', 200)

from sklearn.metrics import f1_score
import os
import numpy as np
from tensorflow.keras.utils import Sequence, to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from typing import List, Tuple
from models.cnn_models import *
import random
img_shape = (64, 64)
# Out:
# Using GPU - /physical_device:GPU:0
# Using device /GPU:0
# Number of CPU cores available: 12

# %%
class CustomMultiInputDataGenerator(Sequence):
    def __init__(self, directories, batch_size=32, image_size=img_shape, shuffle=True, augment=False, num_classes=2, **kwargs):
        """
        directories: List of directories, one for each input branch.
        """
        super().__init__(**kwargs)
        self.directories = directories
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.augment = augment
        self.num_classes = num_classes
        self.image_paths = self._load_image_paths()
        self.samples = len(self.image_paths[0])
        
        self.datagen = ImageDataGenerator(
            rescale=1/255.0,
            width_shift_range=0.1 if self.augment else 0,
            height_shift_range=0.1 if self.augment else 0
        )
        
        self.on_epoch_end()

    def _load_image_paths(self):
        # Load image paths for each branch directory
        image_paths = []
        for directory in self.directories:
            branch_image_paths = [os.path.join(directory, fname) for fname in os.listdir(directory) if fname.endswith('.jpg')]
            image_paths.append(branch_image_paths)
        return image_paths

    def _get_class_from_filename(self, filename):
        # Extract label from filename assuming a naming convention
        class_label = int(filename.split('_')[-1].split('.')[0])
        return class_label

    def __len__(self):
        return int(np.ceil(self.samples / self.batch_size))

    def __getitem__(self, index):
        # Load a batch of images for each branch
        batch_image_paths = [paths[index * self.batch_size:(index + 1) * self.batch_size] for paths in self.image_paths]
        
        # Load and preprocess images for each branch
        images_per_branch = []
        for branch_paths in batch_image_paths:
            images = np.array([img_to_array(load_img(path, target_size=self.image_size)) for path in branch_paths])
            if self.augment:
                images = np.array([self.datagen.random_transform(image) for image in images])
            else:
                images = self.datagen.standardize(images)
            images_per_branch.append(images)

        # Load labels (assuming the same labels for each branch)
        labels = np.array([self._get_class_from_filename(os.path.basename(path)) for path in batch_image_paths[0]])
        labels = to_categorical(labels, num_classes=self.num_classes)
        
        return images_per_branch, labels

    def on_epoch_end(self):
        if self.shuffle:
            for branch_paths in self.image_paths:
                np.random.shuffle(branch_paths)

# %%
DEBUG = True

class FederatedClient:
    def __init__(self, client_id: int, model_fn, train_generator, valid_generator=None):
        self.client_id = client_id
        self.model = model_fn()
        self.train_generator = train_generator
        self.valid_generator = valid_generator
    
    def train(self, global_weights, local_epochs=5):
        # Update local model with global weights
        self.model.set_weights(global_weights)
        if DEBUG:
            print("train_generator:")
            print(len(self.train_generator[0][1]), self.train_generator.samples)
            
        # Train the model locally using the generator
        history = self.model.fit(
            self.train_generator,
            epochs=local_epochs,
            validation_data=self.valid_generator,
            verbose=1
        )
        
        return self.model.get_weights(), history.history

class FederatedServer:
    def __init__(self, model_fn):
        self.global_model = model_fn()
        self.clients = []
        
    def add_client(self, client: FederatedClient):
        self.clients.append(client)
    
    def aggregate_weights(self, client_weights: List[np.ndarray]) -> List[np.ndarray]:
        """FedAvg aggregation with sample weighting"""
        # Get number of samples for each client
        client_samples = [client.train_generator.samples for client in self.clients]
        total_samples = sum(client_samples)
        
        # Calculate weighted average based on number of samples
        weighted_weights = []
        for idx, weights in enumerate(client_weights):
            weight = client_samples[idx] / total_samples
            weighted_weights.append([w * weight for w in weights])
        
        # Sum up the weighted weights
        averaged_weights = [
            sum(weights_list) 
            for weights_list in zip(*weighted_weights)
        ]
        
        return averaged_weights

    def evaluate(self, test_generator):
        """Evaluate the global model on test data"""
        return self.global_model.evaluate(test_generator)


def split_data_for_clients(train_generator, num_clients: int) -> List[List[List[str]]]:
    """
    Split image paths into non-overlapping subsets for each client
    
    Args:
        image_paths_list: List of lists of image paths (one list per branch)
        num_clients: Number of clients to split data for
    
    Returns:
        List of client datasets, where each client dataset contains lists of paths for each branch
    """
    image_paths_list = train_generator.image_paths
    # Ensure all branches have the same number of images
    total_samples = len(image_paths_list[0])
    assert all(len(paths) == total_samples for paths in image_paths_list)
    
    # Create indices for splitting
    indices = list(range(total_samples))
    
    if train_generator.shuffle:
        random.shuffle(indices)
    
    # Calculate samples per client
    samples_per_client = total_samples // num_clients
    
    # Split indices for each client
    client_indices = [
        indices[i * samples_per_client:(i + 1) * samples_per_client]
        for i in range(num_clients)
    ]
    
    # Add remaining samples to the last client
    if total_samples % num_clients != 0:
        remaining = indices[num_clients * samples_per_client:]
        client_indices[-1].extend(remaining)
    
    # Create client datasets
    client_datasets = []
    for client_idx in client_indices:
        client_data = []
        for branch_paths in image_paths_list:
            client_branch_paths = [branch_paths[i] for i in client_idx]
            client_data.append(client_branch_paths)
        client_datasets.append(client_data)
    
    return client_datasets

def create_client_generator(base_generator, client_image_paths):
    """
    Create a new generator for a client with specific image paths
    """
    client_generator = CustomMultiInputDataGenerator(
        directories=base_generator.directories,
        batch_size=base_generator.batch_size,
        image_size=base_generator.image_size,
        shuffle=base_generator.shuffle,
        augment=base_generator.augment,
        num_classes=base_generator.num_classes
    )
    
    # Set the client-specific image paths
    client_generator.image_paths = client_image_paths
    client_generator.samples = len(client_image_paths[0])
    
    return client_generator


def create_federated_learning_system(
    num_clients: int,
    train_generator,
    valid_generator=None,
    input_shape1=(64, 64, 3),
    input_shape2=(64, 64, 3),
    input_shape3=(64, 64, 3),
    num_classes=2
):
    """
    Creates a federated learning system using data generators
    
    Args:
        num_clients: Number of clients to simulate
        train_generator: CustomMultiInputDataGenerator for training
        valid_generator: Optional CustomMultiInputDataGenerator for validation
        input_shape1/2/3: Input shapes for the three branches
        num_classes: Number of output classes
    """
    
    def model_fn():
        return create_multi_input_cnn(
            input_shape1=input_shape1,
            input_shape2=input_shape2,
            input_shape3=input_shape3
        )
    
    # Initialize server
    server = FederatedServer(model_fn)
    
    # Split data among clients
    client_datasets = split_data_for_clients(train_generator, num_clients)
    
    # Create clients with their specific data
    for i, client_image_paths in enumerate(client_datasets):
        # Create client-specific generator
        client_train_generator = create_client_generator(train_generator, client_image_paths)
        
        # Create client
        client = FederatedClient(
            client_id=i,
            model_fn=model_fn,
            train_generator=client_train_generator,
            valid_generator=valid_generator
        )
        server.add_client(client)
        
        print(f"Client {i} created with {client_train_generator.samples} samples")
    
    return server

def train_federated(
    server: FederatedServer,
    num_rounds: int,
    local_epochs: int,
    test_generator=None
) -> dict:
    """
    Train the model using federated learning
    
    Args:
        server: FederatedServer instance
        num_rounds: Number of federated learning rounds
        local_epochs: Number of local epochs per client
        test_generator: Optional generator for testing global model
    """
    metrics_history = []
    
    for round_num in range(num_rounds):
        print(f"\nFederated Learning Round {round_num + 1}/{num_rounds}")
        
        # Get current global weights
        global_weights = server.global_model.get_weights()
        
        # Train each client locally
        client_weights = []
        client_metrics = []
        
        for client in server.clients:
            print(f"\nTraining Client {client.client_id + 1}/{len(server.clients)}")
            weights, metrics = client.train(
                global_weights,
                local_epochs=local_epochs
            )
            client_weights.append(weights)
            client_metrics.append(metrics)
        
        # Aggregate weights using FedAvg
        new_global_weights = server.aggregate_weights(client_weights)
        
        # Update global model
        server.global_model.set_weights(new_global_weights)
        
        # Evaluate global model if test generator is provided
        if test_generator is not None:
            print("\nEvaluating global model:")
            test_metrics = server.evaluate(test_generator)
            test_results = dict(zip(server.global_model.metrics_names, test_metrics))
            print("Test metrics:", test_results)
        
        # Aggregate training metrics
        round_metrics = {
            metric: np.mean([client_metric[metric][-1] 
                           for client_metric in client_metrics])
            for metric in client_metrics[0].keys()
        }
        metrics_history.append(round_metrics)
        
        # Print round metrics
        print("\nRound Training Metrics:")
        for metric, value in round_metrics.items():
            print(f"{metric}: {value:.4f}")
    
    return metrics_history

# %%
train_directories = ["../data/federated_learning_data/AccAP/train", "../data/federated_learning_data/AccML/train", "../data/federated_learning_data/AccV/train"]

val_directories = ["../data/federated_learning_data/AccAP/valid", "../data/federated_learning_data/AccML/valid", "../data/federated_learning_data/AccV/valid"]

train_generator = CustomMultiInputDataGenerator(
    directories=train_directories,
    batch_size=32,
    image_size=img_shape,
    augment=False,
    num_classes=2
)

valid_generator = CustomMultiInputDataGenerator(
    directories=val_directories,
    batch_size=32,
    image_size=img_shape,
    augment=False,
    num_classes=2
)

# %%
server = create_federated_learning_system(
    num_clients=5,
    train_generator=train_generator,
    valid_generator=valid_generator,
    input_shape1=(64, 64, 3),
    input_shape2=(64, 64, 3),
    input_shape3=(64, 64, 3),
    num_classes=2
)

# Train using federated learning
metrics_history = train_federated(
    server,
    num_rounds=10,
    local_epochs=5,
    test_generator=valid_generator
)
# Out:
# Client 0 created with 1657 samples
# Client 1 created with 1657 samples
# Client 2 created with 1657 samples
# Client 3 created with 1657 samples
# Client 4 created with 1660 samples
#
# Federated Learning Round 1/10
#
# Training Client 1/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 109s 2s/step - loss: 1.2860 - accuracy: 0.6494 - precision: 0.6494 - recall: 0.6494 - f1_metric: 0.4646 - val_loss: 1.7055 - val_accuracy: 0.2946 - val_precision: 0.2946 - val_recall: 0.2946 - val_f1_metric: 0.4495
# Epoch 2/5
# 52/52 [==============================] - 56s 1s/step - loss: 1.1210 - accuracy: 0.6874 - precision: 0.6874 - recall: 0.6874 - f1_metric: 0.5048 - val_loss: 2.1581 - val_accuracy: 0.2946 - val_precision: 0.2946 - val_recall: 0.2946 - val_f1_metric: 0.4480
# Epoch 3/5
# 52/52 [==============================] - 56s 1s/step - loss: 1.0182 - accuracy: 0.7339 - precision: 0.7339 - recall: 0.7339 - f1_metric: 0.6130 - val_loss: 1.9402 - val_accuracy: 0.2946 - val_precision: 0.2946 - val_recall: 0.2946 - val_f1_metric: 0.4486
# Epoch 4/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.9738 - accuracy: 0.7339 - precision: 0.7339 - recall: 0.7339 - f1_metric: 0.6281 - val_loss: 1.8228 - val_accuracy: 0.2946 - val_precision: 0.2946 - val_recall: 0.2946 - val_f1_metric: 0.4461
# Epoch 5/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.9334 - accuracy: 0.7670 - precision: 0.7670 - recall: 0.7670 - f1_metric: 0.6770 - val_loss: 1.5144 - val_accuracy: 0.2946 - val_precision: 0.2946 - val_recall: 0.2946 - val_f1_metric: 0.4509
#
# Training Client 2/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 127s 2s/step - loss: 1.2880 - accuracy: 0.6367 - precision: 0.6367 - recall: 0.6367 - f1_metric: 0.4623 - val_loss: 1.5217 - val_accuracy: 0.2946 - val_precision: 0.2946 - val_recall: 0.2946 - val_f1_metric: 0.4524
# Epoch 2/5
# 52/52 [==============================] - 56s 1s/step - loss: 1.0810 - accuracy: 0.7182 - precision: 0.7182 - recall: 0.7182 - f1_metric: 0.5765 - val_loss: 1.8416 - val_accuracy: 0.2946 - val_precision: 0.2946 - val_recall: 0.2946 - val_f1_metric: 0.4494
# Epoch 3/5
# 52/52 [==============================] - 55s 1s/step - loss: 1.0138 - accuracy: 0.7604 - precision: 0.7604 - recall: 0.7604 - f1_metric: 0.6678 - val_loss: 2.3618 - val_accuracy: 0.2946 - val_precision: 0.2946 - val_recall: 0.2946 - val_f1_metric: 0.4499
# Epoch 4/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.9641 - accuracy: 0.7502 - precision: 0.7502 - recall: 0.7502 - f1_metric: 0.6523 - val_loss: 2.0711 - val_accuracy: 0.2946 - val_precision: 0.2946 - val_recall: 0.2946 - val_f1_metric: 0.4495
# Epoch 5/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.9163 - accuracy: 0.7731 - precision: 0.7731 - recall: 0.7731 - f1_metric: 0.6872 - val_loss: 1.9822 - val_accuracy: 0.2967 - val_precision: 0.2967 - val_recall: 0.2967 - val_f1_metric: 0.4493
#
# Training Client 3/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 211s 4s/step - loss: 1.2865 - accuracy: 0.6023 - precision: 0.6023 - recall: 0.6023 - f1_metric: 0.4332 - val_loss: 1.2954 - val_accuracy: 0.2946 - val_precision: 0.2946 - val_recall: 0.2946 - val_f1_metric: 0.4481
# Epoch 2/5
# 52/52 [==============================] - 168s 3s/step - loss: 1.1153 - accuracy: 0.6934 - precision: 0.6934 - recall: 0.6934 - f1_metric: 0.5742 - val_loss: 1.3355 - val_accuracy: 0.2946 - val_precision: 0.2946 - val_recall: 0.2946 - val_f1_metric: 0.4500
# Epoch 3/5
# 52/52 [==============================] - 122s 2s/step - loss: 1.0326 - accuracy: 0.7242 - precision: 0.7242 - recall: 0.7242 - f1_metric: 0.6244 - val_loss: 1.1599 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867 - val_f1_metric: 0.3503
# Epoch 4/5
# 52/52 [==============================] - 113s 2s/step - loss: 0.9721 - accuracy: 0.7634 - precision: 0.7634 - recall: 0.7634 - f1_metric: 0.6790 - val_loss: 1.3660 - val_accuracy: 0.2950 - val_precision: 0.2950 - val_recall: 0.2950 - val_f1_metric: 0.4499
# Epoch 5/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.9304 - accuracy: 0.7592 - precision: 0.7592 - recall: 0.7592 - f1_metric: 0.6835 - val_loss: 1.3880 - val_accuracy: 0.3050 - val_precision: 0.3050 - val_recall: 0.3050 - val_f1_metric: 0.4541
#
# Training Client 4/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 167s 3s/step - loss: 1.2629 - accuracy: 0.6391 - precision: 0.6391 - recall: 0.6391 - f1_metric: 0.4880 - val_loss: 1.5842 - val_accuracy: 0.2946 - val_precision: 0.2946 - val_recall: 0.2946 - val_f1_metric: 0.4498
# Epoch 2/5
# 52/52 [==============================] - 140s 3s/step - loss: 1.1008 - accuracy: 0.7182 - precision: 0.7182 - recall: 0.7182 - f1_metric: 0.5742 - val_loss: 1.8365 - val_accuracy: 0.2946 - val_precision: 0.2946 - val_recall: 0.2946 - val_f1_metric: 0.4490
# Epoch 3/5
# 52/52 [==============================] - 55s 1s/step - loss: 1.0333 - accuracy: 0.7212 - precision: 0.7212 - recall: 0.7212 - f1_metric: 0.6077 - val_loss: 2.1501 - val_accuracy: 0.2946 - val_precision: 0.2946 - val_recall: 0.2946 - val_f1_metric: 0.4491
# Epoch 4/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.9901 - accuracy: 0.7393 - precision: 0.7393 - recall: 0.7393 - f1_metric: 0.6323 - val_loss: 1.4630 - val_accuracy: 0.2954 - val_precision: 0.2954 - val_recall: 0.2954 - val_f1_metric: 0.4526
# Epoch 5/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.9460 - accuracy: 0.7423 - precision: 0.7423 - recall: 0.7423 - f1_metric: 0.6384 - val_loss: 1.1432 - val_accuracy: 0.4494 - val_precision: 0.4494 - val_recall: 0.4494 - val_f1_metric: 0.4673
#
# Training Client 5/5
# train_generator:
# 32 1660
# Epoch 1/5
# 52/52 [==============================] - 182s 4s/step - loss: 1.2370 - accuracy: 0.6765 - precision: 0.6765 - recall: 0.6765 - f1_metric: 0.5448 - val_loss: 1.6741 - val_accuracy: 0.2946 - val_precision: 0.2946 - val_recall: 0.2946 - val_f1_metric: 0.4478
# Epoch 2/5
# 52/52 [==============================] - 56s 1s/step - loss: 1.0651 - accuracy: 0.7476 - precision: 0.7476 - recall: 0.7476 - f1_metric: 0.6451 - val_loss: 2.1519 - val_accuracy: 0.2946 - val_precision: 0.2946 - val_recall: 0.2946 - val_f1_metric: 0.4526
# Epoch 3/5
# 52/52 [==============================] - 55s 1s/step - loss: 1.0097 - accuracy: 0.7627 - precision: 0.7627 - recall: 0.7627 - f1_metric: 0.6691 - val_loss: 1.8655 - val_accuracy: 0.2946 - val_precision: 0.2946 - val_recall: 0.2946 - val_f1_metric: 0.4471
# Epoch 4/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.9611 - accuracy: 0.7717 - precision: 0.7717 - recall: 0.7717 - f1_metric: 0.6920 - val_loss: 1.6151 - val_accuracy: 0.2946 - val_precision: 0.2946 - val_recall: 0.2946 - val_f1_metric: 0.4485
# Epoch 5/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.8934 - accuracy: 0.7867 - precision: 0.7867 - recall: 0.7867 - f1_metric: 0.7162 - val_loss: 2.6852 - val_accuracy: 0.2946 - val_precision: 0.2946 - val_recall: 0.2946 - val_f1_metric: 0.4476
#
# Evaluating global model:
# 76/76 [==============================] - 33s 424ms/step - loss: 2.1460 - accuracy: 0.2946 - precision: 0.2946 - recall: 0.2946 - f1_metric: 0.4468
# Test metrics: {'loss': 2.146035671234131, 'accuracy': 0.2946058213710785, 'precision': 0.2946058213710785, 'recall': 0.2946058213710785, 'f1_metric': 0.4468136429786682}
#
# Round Training Metrics:
# loss: 0.9239
# accuracy: 0.7657
# precision: 0.7657
# recall: 0.7657
# f1_metric: 0.6804
# val_loss: 1.7426
# val_accuracy: 0.3280
# val_precision: 0.3280
# val_recall: 0.3280
# val_f1_metric: 0.4538
#
# Federated Learning Round 2/10
#
# Training Client 1/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 127s 2s/step - loss: 0.8716 - accuracy: 0.7622 - precision: 0.7622 - recall: 0.7622 - f1_metric: 0.6582 - val_loss: 1.8398 - val_accuracy: 0.2946 - val_precision: 0.2946 - val_recall: 0.2946 - val_f1_metric: 0.4477
# Epoch 2/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.8644 - accuracy: 0.7465 - precision: 0.7465 - recall: 0.7465 - f1_metric: 0.6390 - val_loss: 1.3905 - val_accuracy: 0.3129 - val_precision: 0.3129 - val_recall: 0.3129 - val_f1_metric: 0.4561
# Epoch 3/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.8176 - accuracy: 0.7701 - precision: 0.7701 - recall: 0.7701 - f1_metric: 0.6881 - val_loss: 1.0037 - val_accuracy: 0.5336 - val_precision: 0.5336 - val_recall: 0.5336 - val_f1_metric: 0.4588
# Epoch 4/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.7749 - accuracy: 0.7785 - precision: 0.7785 - recall: 0.7785 - f1_metric: 0.6806 - val_loss: 0.8916 - val_accuracy: 0.6635 - val_precision: 0.6635 - val_recall: 0.6635 - val_f1_metric: 0.4560
# Epoch 5/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.7409 - accuracy: 0.7815 - precision: 0.7815 - recall: 0.7815 - f1_metric: 0.7010 - val_loss: 0.8840 - val_accuracy: 0.6581 - val_precision: 0.6581 - val_recall: 0.6581 - val_f1_metric: 0.4699
#
# Training Client 2/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 141s 3s/step - loss: 0.8682 - accuracy: 0.7683 - precision: 0.7683 - recall: 0.7683 - f1_metric: 0.6767 - val_loss: 1.6307 - val_accuracy: 0.3025 - val_precision: 0.3025 - val_recall: 0.3025 - val_f1_metric: 0.4491
# Epoch 2/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.8311 - accuracy: 0.7767 - precision: 0.7767 - recall: 0.7767 - f1_metric: 0.7076 - val_loss: 1.2406 - val_accuracy: 0.4071 - val_precision: 0.4071 - val_recall: 0.4071 - val_f1_metric: 0.4821
# Epoch 3/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.7998 - accuracy: 0.7815 - precision: 0.7815 - recall: 0.7815 - f1_metric: 0.6974 - val_loss: 1.5470 - val_accuracy: 0.3755 - val_precision: 0.3755 - val_recall: 0.3755 - val_f1_metric: 0.4786
# Epoch 4/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.7650 - accuracy: 0.7809 - precision: 0.7809 - recall: 0.7809 - f1_metric: 0.7085 - val_loss: 1.7594 - val_accuracy: 0.3133 - val_precision: 0.3133 - val_recall: 0.3133 - val_f1_metric: 0.4584
# Epoch 5/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.7231 - accuracy: 0.7839 - precision: 0.7839 - recall: 0.7839 - f1_metric: 0.6977 - val_loss: 1.8155 - val_accuracy: 0.3813 - val_precision: 0.3813 - val_recall: 0.3813 - val_f1_metric: 0.4818
#
# Training Client 3/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 118s 2s/step - loss: 0.8800 - accuracy: 0.7628 - precision: 0.7628 - recall: 0.7628 - f1_metric: 0.6774 - val_loss: 2.0365 - val_accuracy: 0.2950 - val_precision: 0.2950 - val_recall: 0.2950 - val_f1_metric: 0.4467
# Epoch 2/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.8534 - accuracy: 0.7495 - precision: 0.7495 - recall: 0.7495 - f1_metric: 0.6583 - val_loss: 1.7723 - val_accuracy: 0.3000 - val_precision: 0.3000 - val_recall: 0.3000 - val_f1_metric: 0.4489
# Epoch 3/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.8005 - accuracy: 0.7839 - precision: 0.7839 - recall: 0.7839 - f1_metric: 0.7144 - val_loss: 1.1558 - val_accuracy: 0.5037 - val_precision: 0.5037 - val_recall: 0.5037 - val_f1_metric: 0.5093
# Epoch 4/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.7682 - accuracy: 0.7888 - precision: 0.7888 - recall: 0.7888 - f1_metric: 0.7230 - val_loss: 1.2285 - val_accuracy: 0.3568 - val_precision: 0.3568 - val_recall: 0.3568 - val_f1_metric: 0.4696
# Epoch 5/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.7457 - accuracy: 0.7797 - precision: 0.7797 - recall: 0.7797 - f1_metric: 0.7101 - val_loss: 0.9037 - val_accuracy: 0.6274 - val_precision: 0.6274 - val_recall: 0.6274 - val_f1_metric: 0.4687
#
# Training Client 4/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 81s 2s/step - loss: 0.8775 - accuracy: 0.7683 - precision: 0.7683 - recall: 0.7683 - f1_metric: 0.6870 - val_loss: 2.1281 - val_accuracy: 0.2946 - val_precision: 0.2946 - val_recall: 0.2946 - val_f1_metric: 0.4507
# Epoch 2/5
# 52/52 [==============================] - 57s 1s/step - loss: 0.8710 - accuracy: 0.7465 - precision: 0.7465 - recall: 0.7465 - f1_metric: 0.6540 - val_loss: 1.4452 - val_accuracy: 0.3154 - val_precision: 0.3154 - val_recall: 0.3154 - val_f1_metric: 0.4553
# Epoch 3/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.8287 - accuracy: 0.7568 - precision: 0.7568 - recall: 0.7568 - f1_metric: 0.6756 - val_loss: 1.4197 - val_accuracy: 0.3324 - val_precision: 0.3324 - val_recall: 0.3324 - val_f1_metric: 0.4622
# Epoch 4/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.7983 - accuracy: 0.7580 - precision: 0.7580 - recall: 0.7580 - f1_metric: 0.6865 - val_loss: 0.8852 - val_accuracy: 0.6622 - val_precision: 0.6622 - val_recall: 0.6622 - val_f1_metric: 0.5203
# Epoch 5/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.7431 - accuracy: 0.7664 - precision: 0.7664 - recall: 0.7664 - f1_metric: 0.6866 - val_loss: 0.9078 - val_accuracy: 0.6195 - val_precision: 0.6195 - val_recall: 0.6195 - val_f1_metric: 0.5454
#
# Training Client 5/5
# train_generator:
# 32 1660
# Epoch 1/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.8454 - accuracy: 0.7759 - precision: 0.7759 - recall: 0.7759 - f1_metric: 0.7023 - val_loss: 1.8298 - val_accuracy: 0.2946 - val_precision: 0.2946 - val_recall: 0.2946 - val_f1_metric: 0.4497
# Epoch 2/5
# 52/52 [==============================] - 57s 1s/step - loss: 0.8230 - accuracy: 0.7849 - precision: 0.7849 - recall: 0.7849 - f1_metric: 0.7187 - val_loss: 2.0506 - val_accuracy: 0.2946 - val_precision: 0.2946 - val_recall: 0.2946 - val_f1_metric: 0.4492
# Epoch 3/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.7840 - accuracy: 0.7855 - precision: 0.7855 - recall: 0.7855 - f1_metric: 0.7154 - val_loss: 1.1583 - val_accuracy: 0.4162 - val_precision: 0.4162 - val_recall: 0.4162 - val_f1_metric: 0.4867
# Epoch 4/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.7507 - accuracy: 0.7898 - precision: 0.7898 - recall: 0.7898 - f1_metric: 0.7265 - val_loss: 1.2079 - val_accuracy: 0.4643 - val_precision: 0.4643 - val_recall: 0.4643 - val_f1_metric: 0.5086
# Epoch 5/5
# 52/52 [==============================] - 58s 1s/step - loss: 0.7032 - accuracy: 0.8066 - precision: 0.8066 - recall: 0.8066 - f1_metric: 0.7417 - val_loss: 0.8665 - val_accuracy: 0.6784 - val_precision: 0.6784 - val_recall: 0.6784 - val_f1_metric: 0.5036
#
# Evaluating global model:
# 76/76 [==============================] - 34s 449ms/step - loss: 0.9194 - accuracy: 0.6295 - precision: 0.6295 - recall: 0.6295 - f1_metric: 0.5195
# Test metrics: {'loss': 0.9193907380104065, 'accuracy': 0.6294605731964111, 'precision': 0.6294605731964111, 'recall': 0.6294605731964111, 'f1_metric': 0.5195085406303406}
#
# Round Training Metrics:
# loss: 0.7312
# accuracy: 0.7837
# precision: 0.7837
# recall: 0.7837
# f1_metric: 0.7074
# val_loss: 1.0755
# val_accuracy: 0.5929
# val_precision: 0.5929
# val_recall: 0.5929
# val_f1_metric: 0.4939
#
# Federated Learning Round 3/10
#
# Training Client 1/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 101s 2s/step - loss: 0.7332 - accuracy: 0.7683 - precision: 0.7683 - recall: 0.7683 - f1_metric: 0.6758 - val_loss: 0.8238 - val_accuracy: 0.6793 - val_precision: 0.6793 - val_recall: 0.6793 - val_f1_metric: 0.3774
# Epoch 2/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.6988 - accuracy: 0.7725 - precision: 0.7725 - recall: 0.7725 - f1_metric: 0.6929 - val_loss: 0.8525 - val_accuracy: 0.6183 - val_precision: 0.6183 - val_recall: 0.6183 - val_f1_metric: 0.4991
# Epoch 3/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.6674 - accuracy: 0.7761 - precision: 0.7761 - recall: 0.7761 - f1_metric: 0.6974 - val_loss: 0.8000 - val_accuracy: 0.6763 - val_precision: 0.6763 - val_recall: 0.6763 - val_f1_metric: 0.4714
# Epoch 4/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.6455 - accuracy: 0.7906 - precision: 0.7906 - recall: 0.7906 - f1_metric: 0.7230 - val_loss: 0.7773 - val_accuracy: 0.6863 - val_precision: 0.6863 - val_recall: 0.6863 - val_f1_metric: 0.1998
# Epoch 5/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.6467 - accuracy: 0.7737 - precision: 0.7737 - recall: 0.7737 - f1_metric: 0.6845 - val_loss: 1.2414 - val_accuracy: 0.4008 - val_precision: 0.4008 - val_recall: 0.4008 - val_f1_metric: 0.4844
#
# Training Client 2/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.6935 - accuracy: 0.7966 - precision: 0.7966 - recall: 0.7966 - f1_metric: 0.7311 - val_loss: 0.9302 - val_accuracy: 0.6270 - val_precision: 0.6270 - val_recall: 0.6270 - val_f1_metric: 0.5456
# Epoch 2/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.6728 - accuracy: 0.7918 - precision: 0.7918 - recall: 0.7918 - f1_metric: 0.7217 - val_loss: 0.9591 - val_accuracy: 0.5087 - val_precision: 0.5087 - val_recall: 0.5087 - val_f1_metric: 0.5151
# Epoch 3/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.6553 - accuracy: 0.7924 - precision: 0.7924 - recall: 0.7924 - f1_metric: 0.7272 - val_loss: 0.8041 - val_accuracy: 0.6689 - val_precision: 0.6689 - val_recall: 0.6689 - val_f1_metric: 0.4979
# Epoch 4/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.6406 - accuracy: 0.7972 - precision: 0.7972 - recall: 0.7972 - f1_metric: 0.7245 - val_loss: 0.9071 - val_accuracy: 0.6539 - val_precision: 0.6539 - val_recall: 0.6539 - val_f1_metric: 0.4608
# Epoch 5/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.6098 - accuracy: 0.8002 - precision: 0.8002 - recall: 0.8002 - f1_metric: 0.7367 - val_loss: 0.8268 - val_accuracy: 0.6340 - val_precision: 0.6340 - val_recall: 0.6340 - val_f1_metric: 0.4826
#
# Training Client 3/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.7233 - accuracy: 0.7725 - precision: 0.7725 - recall: 0.7725 - f1_metric: 0.6912 - val_loss: 0.8001 - val_accuracy: 0.6905 - val_precision: 0.6905 - val_recall: 0.6905 - val_f1_metric: 0.4533
# Epoch 2/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.6998 - accuracy: 0.7755 - precision: 0.7755 - recall: 0.7755 - f1_metric: 0.7059 - val_loss: 0.8183 - val_accuracy: 0.6739 - val_precision: 0.6739 - val_recall: 0.6739 - val_f1_metric: 0.4524
# Epoch 3/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.6627 - accuracy: 0.7773 - precision: 0.7773 - recall: 0.7773 - f1_metric: 0.7095 - val_loss: 0.7581 - val_accuracy: 0.6842 - val_precision: 0.6842 - val_recall: 0.6842 - val_f1_metric: 0.2549
# Epoch 4/5
# 52/52 [==============================] - 57s 1s/step - loss: 0.6454 - accuracy: 0.7924 - precision: 0.7924 - recall: 0.7924 - f1_metric: 0.7213 - val_loss: 0.7194 - val_accuracy: 0.6975 - val_precision: 0.6975 - val_recall: 0.6975 - val_f1_metric: 0.2682
# Epoch 5/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.6177 - accuracy: 0.7815 - precision: 0.7815 - recall: 0.7815 - f1_metric: 0.7157 - val_loss: 0.7397 - val_accuracy: 0.6967 - val_precision: 0.6967 - val_recall: 0.6967 - val_f1_metric: 0.1111
#
# Training Client 4/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.7303 - accuracy: 0.7622 - precision: 0.7622 - recall: 0.7622 - f1_metric: 0.6844 - val_loss: 0.8441 - val_accuracy: 0.6739 - val_precision: 0.6739 - val_recall: 0.6739 - val_f1_metric: 0.4800
# Epoch 2/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.7062 - accuracy: 0.7628 - precision: 0.7628 - recall: 0.7628 - f1_metric: 0.6883 - val_loss: 0.7954 - val_accuracy: 0.6983 - val_precision: 0.6983 - val_recall: 0.6983 - val_f1_metric: 0.2943
# Epoch 3/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.6912 - accuracy: 0.7610 - precision: 0.7610 - recall: 0.7610 - f1_metric: 0.6963 - val_loss: 0.8145 - val_accuracy: 0.6863 - val_precision: 0.6863 - val_recall: 0.6863 - val_f1_metric: 0.4697
# Epoch 4/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.6324 - accuracy: 0.7846 - precision: 0.7846 - recall: 0.7846 - f1_metric: 0.7117 - val_loss: 0.7683 - val_accuracy: 0.6934 - val_precision: 0.6934 - val_recall: 0.6934 - val_f1_metric: 0.3238
# Epoch 5/5
# 52/52 [==============================] - 57s 1s/step - loss: 0.6452 - accuracy: 0.7731 - precision: 0.7731 - recall: 0.7731 - f1_metric: 0.7029 - val_loss: 0.8590 - val_accuracy: 0.6220 - val_precision: 0.6220 - val_recall: 0.6220 - val_f1_metric: 0.5499
#
# Training Client 5/5
# train_generator:
# 32 1660
# Epoch 1/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.6915 - accuracy: 0.8000 - precision: 0.8000 - recall: 0.8000 - f1_metric: 0.7417 - val_loss: 0.8182 - val_accuracy: 0.6755 - val_precision: 0.6755 - val_recall: 0.6755 - val_f1_metric: 0.5128
# Epoch 2/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.6534 - accuracy: 0.8181 - precision: 0.8181 - recall: 0.8181 - f1_metric: 0.7650 - val_loss: 0.8060 - val_accuracy: 0.6651 - val_precision: 0.6651 - val_recall: 0.6651 - val_f1_metric: 0.4970
# Epoch 3/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.6312 - accuracy: 0.8139 - precision: 0.8139 - recall: 0.8139 - f1_metric: 0.7482 - val_loss: 0.8260 - val_accuracy: 0.6149 - val_precision: 0.6149 - val_recall: 0.6149 - val_f1_metric: 0.5419
# Epoch 4/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.6204 - accuracy: 0.8078 - precision: 0.8078 - recall: 0.8078 - f1_metric: 0.7481 - val_loss: 0.8267 - val_accuracy: 0.7017 - val_precision: 0.7017 - val_recall: 0.7017 - val_f1_metric: 0.4604
# Epoch 5/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.5906 - accuracy: 0.8133 - precision: 0.8133 - recall: 0.8133 - f1_metric: 0.7624 - val_loss: 0.7654 - val_accuracy: 0.6743 - val_precision: 0.6743 - val_recall: 0.6743 - val_f1_metric: 0.4848
#
# Evaluating global model:
# 76/76 [==============================] - 33s 434ms/step - loss: 0.7612 - accuracy: 0.6718 - precision: 0.6718 - recall: 0.6718 - f1_metric: 0.4920
# Test metrics: {'loss': 0.761219322681427, 'accuracy': 0.6717842221260071, 'precision': 0.6717842221260071, 'recall': 0.6717842221260071, 'f1_metric': 0.4919755458831787}
#
# Round Training Metrics:
# loss: 0.6220
# accuracy: 0.7884
# precision: 0.7884
# recall: 0.7884
# f1_metric: 0.7204
# val_loss: 0.8865
# val_accuracy: 0.6056
# val_precision: 0.6056
# val_recall: 0.6056
# val_f1_metric: 0.4226
#
# Federated Learning Round 4/10
#
# Training Client 1/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.6284 - accuracy: 0.7773 - precision: 0.7773 - recall: 0.7773 - f1_metric: 0.7046 - val_loss: 0.7345 - val_accuracy: 0.6929 - val_precision: 0.6929 - val_recall: 0.6929 - val_f1_metric: 0.4048
# Epoch 2/5
# 52/52 [==============================] - 57s 1s/step - loss: 0.6115 - accuracy: 0.7779 - precision: 0.7779 - recall: 0.7779 - f1_metric: 0.7013 - val_loss: 0.8459 - val_accuracy: 0.5066 - val_precision: 0.5066 - val_recall: 0.5066 - val_f1_metric: 0.4864
# Epoch 3/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.5989 - accuracy: 0.7846 - precision: 0.7846 - recall: 0.7846 - f1_metric: 0.7085 - val_loss: 0.7294 - val_accuracy: 0.6714 - val_precision: 0.6714 - val_recall: 0.6714 - val_f1_metric: 0.4349
# Epoch 4/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.5885 - accuracy: 0.7809 - precision: 0.7809 - recall: 0.7809 - f1_metric: 0.7094 - val_loss: 0.7159 - val_accuracy: 0.6950 - val_precision: 0.6950 - val_recall: 0.6950 - val_f1_metric: 0.4573
# Epoch 5/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.5666 - accuracy: 0.7966 - precision: 0.7966 - recall: 0.7966 - f1_metric: 0.7149 - val_loss: 0.7930 - val_accuracy: 0.6286 - val_precision: 0.6286 - val_recall: 0.6286 - val_f1_metric: 0.5035
#
# Training Client 2/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.5969 - accuracy: 0.7894 - precision: 0.7894 - recall: 0.7894 - f1_metric: 0.7215 - val_loss: 0.7283 - val_accuracy: 0.6797 - val_precision: 0.6797 - val_recall: 0.6797 - val_f1_metric: 0.4577
# Epoch 2/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.5704 - accuracy: 0.7966 - precision: 0.7966 - recall: 0.7966 - f1_metric: 0.7340 - val_loss: 0.9040 - val_accuracy: 0.5382 - val_precision: 0.5382 - val_recall: 0.5382 - val_f1_metric: 0.5260
# Epoch 3/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.5524 - accuracy: 0.8075 - precision: 0.8075 - recall: 0.8075 - f1_metric: 0.7429 - val_loss: 0.7406 - val_accuracy: 0.6992 - val_precision: 0.6992 - val_recall: 0.6992 - val_f1_metric: 0.4270
# Epoch 4/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.5399 - accuracy: 0.8033 - precision: 0.8033 - recall: 0.8033 - f1_metric: 0.7433 - val_loss: 0.7691 - val_accuracy: 0.5784 - val_precision: 0.5784 - val_recall: 0.5784 - val_f1_metric: 0.5055
# Epoch 5/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.5296 - accuracy: 0.8039 - precision: 0.8039 - recall: 0.8039 - f1_metric: 0.7461 - val_loss: 0.8225 - val_accuracy: 0.6929 - val_precision: 0.6929 - val_recall: 0.6929 - val_f1_metric: 0.4674
#
# Training Client 3/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.6046 - accuracy: 0.7900 - precision: 0.7900 - recall: 0.7900 - f1_metric: 0.7260 - val_loss: 0.7374 - val_accuracy: 0.6900 - val_precision: 0.6900 - val_recall: 0.6900 - val_f1_metric: 0.4596
# Epoch 2/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.6087 - accuracy: 0.7876 - precision: 0.7876 - recall: 0.7876 - f1_metric: 0.7204 - val_loss: 0.7964 - val_accuracy: 0.6888 - val_precision: 0.6888 - val_recall: 0.6888 - val_f1_metric: 0.3722
# Epoch 3/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.5797 - accuracy: 0.7936 - precision: 0.7936 - recall: 0.7936 - f1_metric: 0.7326 - val_loss: 1.0925 - val_accuracy: 0.4008 - val_precision: 0.4008 - val_recall: 0.4008 - val_f1_metric: 0.4864
# Epoch 4/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.5657 - accuracy: 0.7924 - precision: 0.7924 - recall: 0.7924 - f1_metric: 0.7306 - val_loss: 0.7136 - val_accuracy: 0.6788 - val_precision: 0.6788 - val_recall: 0.6788 - val_f1_metric: 0.4440
# Epoch 5/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.5415 - accuracy: 0.8075 - precision: 0.8075 - recall: 0.8075 - f1_metric: 0.7448 - val_loss: 0.8311 - val_accuracy: 0.5763 - val_precision: 0.5763 - val_recall: 0.5763 - val_f1_metric: 0.5255
#
# Training Client 4/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.6167 - accuracy: 0.7833 - precision: 0.7833 - recall: 0.7833 - f1_metric: 0.7142 - val_loss: 0.6945 - val_accuracy: 0.7025 - val_precision: 0.7025 - val_recall: 0.7025 - val_f1_metric: 0.4528
# Epoch 2/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.5974 - accuracy: 0.7864 - precision: 0.7864 - recall: 0.7864 - f1_metric: 0.7172 - val_loss: 0.7024 - val_accuracy: 0.6876 - val_precision: 0.6876 - val_recall: 0.6876 - val_f1_metric: 0.4574
# Epoch 3/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.5835 - accuracy: 0.7785 - precision: 0.7785 - recall: 0.7785 - f1_metric: 0.7164 - val_loss: 0.7466 - val_accuracy: 0.6975 - val_precision: 0.6975 - val_recall: 0.6975 - val_f1_metric: 0.0519
# Epoch 4/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.5677 - accuracy: 0.7858 - precision: 0.7858 - recall: 0.7858 - f1_metric: 0.7212 - val_loss: 0.8963 - val_accuracy: 0.7025 - val_precision: 0.7025 - val_recall: 0.7025 - val_f1_metric: 0.4228
# Epoch 5/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.5550 - accuracy: 0.7996 - precision: 0.7996 - recall: 0.7996 - f1_metric: 0.7376 - val_loss: 0.7258 - val_accuracy: 0.6361 - val_precision: 0.6361 - val_recall: 0.6361 - val_f1_metric: 0.5382
#
# Training Client 5/5
# train_generator:
# 32 1660
# Epoch 1/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.5803 - accuracy: 0.7988 - precision: 0.7988 - recall: 0.7988 - f1_metric: 0.7356 - val_loss: 0.8019 - val_accuracy: 0.6245 - val_precision: 0.6245 - val_recall: 0.6245 - val_f1_metric: 0.5287
# Epoch 2/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.5668 - accuracy: 0.8078 - precision: 0.8078 - recall: 0.8078 - f1_metric: 0.7520 - val_loss: 0.7733 - val_accuracy: 0.6378 - val_precision: 0.6378 - val_recall: 0.6378 - val_f1_metric: 0.5016
# Epoch 3/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.5454 - accuracy: 0.8271 - precision: 0.8271 - recall: 0.8271 - f1_metric: 0.7813 - val_loss: 0.7666 - val_accuracy: 0.6934 - val_precision: 0.6934 - val_recall: 0.6934 - val_f1_metric: 0.3584
# Epoch 4/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.5254 - accuracy: 0.8211 - precision: 0.8211 - recall: 0.8211 - f1_metric: 0.7666 - val_loss: 0.7041 - val_accuracy: 0.6946 - val_precision: 0.6946 - val_recall: 0.6946 - val_f1_metric: 0.1244
# Epoch 5/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.5143 - accuracy: 0.8283 - precision: 0.8283 - recall: 0.8283 - f1_metric: 0.7814 - val_loss: 0.8644 - val_accuracy: 0.5938 - val_precision: 0.5938 - val_recall: 0.5938 - val_f1_metric: 0.5287
#
# Evaluating global model:
# 76/76 [==============================] - 33s 430ms/step - loss: 0.7461 - accuracy: 0.6295 - precision: 0.6295 - recall: 0.6295 - f1_metric: 0.5229
# Test metrics: {'loss': 0.7460755109786987, 'accuracy': 0.6294605731964111, 'precision': 0.6294605731964111, 'recall': 0.6294605731964111, 'f1_metric': 0.522904098033905}
#
# Round Training Metrics:
# loss: 0.5414
# accuracy: 0.8072
# precision: 0.8072
# recall: 0.8072
# f1_metric: 0.7450
# val_loss: 0.8074
# val_accuracy: 0.6256
# val_precision: 0.6256
# val_recall: 0.6256
# val_f1_metric: 0.5127
#
# Federated Learning Round 5/10
#
# Training Client 1/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.5597 - accuracy: 0.7864 - precision: 0.7864 - recall: 0.7864 - f1_metric: 0.7049 - val_loss: 0.8957 - val_accuracy: 0.5660 - val_precision: 0.5660 - val_recall: 0.5660 - val_f1_metric: 0.5239
# Epoch 2/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.5570 - accuracy: 0.7894 - precision: 0.7894 - recall: 0.7894 - f1_metric: 0.7093 - val_loss: 0.6420 - val_accuracy: 0.6892 - val_precision: 0.6892 - val_recall: 0.6892 - val_f1_metric: 0.3674
# Epoch 3/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.5396 - accuracy: 0.7858 - precision: 0.7858 - recall: 0.7858 - f1_metric: 0.7009 - val_loss: 0.6706 - val_accuracy: 0.6929 - val_precision: 0.6929 - val_recall: 0.6929 - val_f1_metric: 0.0838
# Epoch 4/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.5311 - accuracy: 0.8021 - precision: 0.8021 - recall: 0.8021 - f1_metric: 0.7289 - val_loss: 0.8521 - val_accuracy: 0.6983 - val_precision: 0.6983 - val_recall: 0.6983 - val_f1_metric: 0.0651
# Epoch 5/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.5276 - accuracy: 0.7888 - precision: 0.7888 - recall: 0.7888 - f1_metric: 0.7084 - val_loss: 0.7638 - val_accuracy: 0.6564 - val_precision: 0.6564 - val_recall: 0.6564 - val_f1_metric: 0.5237
#
# Training Client 2/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 61s 1s/step - loss: 0.5216 - accuracy: 0.8014 - precision: 0.8014 - recall: 0.8014 - f1_metric: 0.7399 - val_loss: 0.6903 - val_accuracy: 0.6971 - val_precision: 0.6971 - val_recall: 0.6971 - val_f1_metric: 0.4326
# Epoch 2/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.5205 - accuracy: 0.8057 - precision: 0.8057 - recall: 0.8057 - f1_metric: 0.7421 - val_loss: 0.6709 - val_accuracy: 0.7008 - val_precision: 0.7008 - val_recall: 0.7008 - val_f1_metric: 0.0288
# Epoch 3/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.5048 - accuracy: 0.8081 - precision: 0.8081 - recall: 0.8081 - f1_metric: 0.7559 - val_loss: 0.7250 - val_accuracy: 0.6382 - val_precision: 0.6382 - val_recall: 0.6382 - val_f1_metric: 0.5407
# Epoch 4/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.4949 - accuracy: 0.8147 - precision: 0.8147 - recall: 0.8147 - f1_metric: 0.7512 - val_loss: 0.7031 - val_accuracy: 0.7046 - val_precision: 0.7046 - val_recall: 0.7046 - val_f1_metric: 0.0087
# Epoch 5/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4980 - accuracy: 0.8093 - precision: 0.8093 - recall: 0.8093 - f1_metric: 0.7511 - val_loss: 0.7066 - val_accuracy: 0.6672 - val_precision: 0.6672 - val_recall: 0.6672 - val_f1_metric: 0.5519
#
# Training Client 3/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 63s 1s/step - loss: 0.5381 - accuracy: 0.7936 - precision: 0.7936 - recall: 0.7936 - f1_metric: 0.7329 - val_loss: 0.7136 - val_accuracy: 0.6954 - val_precision: 0.6954 - val_recall: 0.6954 - val_f1_metric: 0.4333
# Epoch 2/5
# 52/52 [==============================] - 58s 1s/step - loss: 0.5337 - accuracy: 0.8033 - precision: 0.8033 - recall: 0.8033 - f1_metric: 0.7464 - val_loss: 0.7515 - val_accuracy: 0.7021 - val_precision: 0.7021 - val_recall: 0.7021 - val_f1_metric: 0.3226
# Epoch 3/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.5209 - accuracy: 0.8045 - precision: 0.8045 - recall: 0.8045 - f1_metric: 0.7463 - val_loss: 0.7480 - val_accuracy: 0.6398 - val_precision: 0.6398 - val_recall: 0.6398 - val_f1_metric: 0.4688
# Epoch 4/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.5153 - accuracy: 0.8099 - precision: 0.8099 - recall: 0.8099 - f1_metric: 0.7498 - val_loss: 0.7072 - val_accuracy: 0.6635 - val_precision: 0.6635 - val_recall: 0.6635 - val_f1_metric: 0.4891
# Epoch 5/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.4888 - accuracy: 0.8189 - precision: 0.8189 - recall: 0.8189 - f1_metric: 0.7596 - val_loss: 0.9397 - val_accuracy: 0.5905 - val_precision: 0.5905 - val_recall: 0.5905 - val_f1_metric: 0.5414
#
# Training Client 4/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 57s 1s/step - loss: 0.5500 - accuracy: 0.7906 - precision: 0.7906 - recall: 0.7906 - f1_metric: 0.7197 - val_loss: 0.7476 - val_accuracy: 0.6917 - val_precision: 0.6917 - val_recall: 0.6917 - val_f1_metric: 0.2457
# Epoch 2/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.5407 - accuracy: 0.7870 - precision: 0.7870 - recall: 0.7870 - f1_metric: 0.7247 - val_loss: 0.7059 - val_accuracy: 0.6979 - val_precision: 0.6979 - val_recall: 0.6979 - val_f1_metric: 0.1644
# Epoch 3/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.5304 - accuracy: 0.7984 - precision: 0.7984 - recall: 0.7984 - f1_metric: 0.7425 - val_loss: 0.9881 - val_accuracy: 0.4817 - val_precision: 0.4817 - val_recall: 0.4817 - val_f1_metric: 0.5033
# Epoch 4/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.5061 - accuracy: 0.8039 - precision: 0.8039 - recall: 0.8039 - f1_metric: 0.7445 - val_loss: 0.6380 - val_accuracy: 0.6876 - val_precision: 0.6876 - val_recall: 0.6876 - val_f1_metric: 0.4663
# Epoch 5/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.5111 - accuracy: 0.8033 - precision: 0.8033 - recall: 0.8033 - f1_metric: 0.7403 - val_loss: 0.6926 - val_accuracy: 0.6996 - val_precision: 0.6996 - val_recall: 0.6996 - val_f1_metric: 0.3762
#
# Training Client 5/5
# train_generator:
# 32 1660
# Epoch 1/5
# 52/52 [==============================] - 57s 1s/step - loss: 0.5217 - accuracy: 0.8193 - precision: 0.8193 - recall: 0.8193 - f1_metric: 0.7639 - val_loss: 0.8037 - val_accuracy: 0.6004 - val_precision: 0.6004 - val_recall: 0.6004 - val_f1_metric: 0.5219
# Epoch 2/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.5208 - accuracy: 0.8108 - precision: 0.8108 - recall: 0.8108 - f1_metric: 0.7513 - val_loss: 0.7180 - val_accuracy: 0.6577 - val_precision: 0.6577 - val_recall: 0.6577 - val_f1_metric: 0.5314
# Epoch 3/5
# 52/52 [==============================] - 57s 1s/step - loss: 0.5181 - accuracy: 0.8048 - precision: 0.8048 - recall: 0.8048 - f1_metric: 0.7503 - val_loss: 0.7408 - val_accuracy: 0.6938 - val_precision: 0.6938 - val_recall: 0.6938 - val_f1_metric: 0.3765
# Epoch 4/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.4786 - accuracy: 0.8343 - precision: 0.8343 - recall: 0.8343 - f1_metric: 0.7824 - val_loss: 0.7262 - val_accuracy: 0.7054 - val_precision: 0.7054 - val_recall: 0.7054 - val_f1_metric: 0.0000e+00
# Epoch 5/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.4660 - accuracy: 0.8265 - precision: 0.8265 - recall: 0.8265 - f1_metric: 0.7772 - val_loss: 0.6884 - val_accuracy: 0.7017 - val_precision: 0.7017 - val_recall: 0.7017 - val_f1_metric: 0.1744
#
# Evaluating global model:
# 76/76 [==============================] - 33s 435ms/step - loss: 0.6656 - accuracy: 0.6892 - precision: 0.6892 - recall: 0.6892 - f1_metric: 0.4755
# Test metrics: {'loss': 0.6655941009521484, 'accuracy': 0.6892116069793701, 'precision': 0.6892116069793701, 'recall': 0.6892116069793701, 'f1_metric': 0.47547903656959534}
#
# Round Training Metrics:
# loss: 0.4983
# accuracy: 0.8094
# precision: 0.8094
# recall: 0.8094
# f1_metric: 0.7473
# val_loss: 0.7582
# val_accuracy: 0.6631
# val_precision: 0.6631
# val_recall: 0.6631
# val_f1_metric: 0.4335
#
# Federated Learning Round 6/10
#
# Training Client 1/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 87s 2s/step - loss: 0.5330 - accuracy: 0.7821 - precision: 0.7821 - recall: 0.7821 - f1_metric: 0.7084 - val_loss: 0.8240 - val_accuracy: 0.7054 - val_precision: 0.7054 - val_recall: 0.7054 - val_f1_metric: 0.0000e+00
# Epoch 2/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.5105 - accuracy: 0.7930 - precision: 0.7930 - recall: 0.7930 - f1_metric: 0.7240 - val_loss: 0.6735 - val_accuracy: 0.6905 - val_precision: 0.6905 - val_recall: 0.6905 - val_f1_metric: 0.1757
# Epoch 3/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.4889 - accuracy: 0.8105 - precision: 0.8105 - recall: 0.8105 - f1_metric: 0.7371 - val_loss: 1.0342 - val_accuracy: 0.6971 - val_precision: 0.6971 - val_recall: 0.6971 - val_f1_metric: 0.2396
# Epoch 4/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4999 - accuracy: 0.7984 - precision: 0.7984 - recall: 0.7984 - f1_metric: 0.7276 - val_loss: 0.8138 - val_accuracy: 0.6336 - val_precision: 0.6336 - val_recall: 0.6336 - val_f1_metric: 0.4892
# Epoch 5/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4923 - accuracy: 0.8111 - precision: 0.8111 - recall: 0.8111 - f1_metric: 0.7358 - val_loss: 0.7087 - val_accuracy: 0.6104 - val_precision: 0.6104 - val_recall: 0.6104 - val_f1_metric: 0.4784
#
# Training Client 2/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 57s 1s/step - loss: 0.4912 - accuracy: 0.8123 - precision: 0.8123 - recall: 0.8123 - f1_metric: 0.7545 - val_loss: 0.7149 - val_accuracy: 0.6909 - val_precision: 0.6909 - val_recall: 0.6909 - val_f1_metric: 0.1949
# Epoch 2/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.4751 - accuracy: 0.8123 - precision: 0.8123 - recall: 0.8123 - f1_metric: 0.7561 - val_loss: 0.6095 - val_accuracy: 0.7046 - val_precision: 0.7046 - val_recall: 0.7046 - val_f1_metric: 0.4055
# Epoch 3/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.4720 - accuracy: 0.8177 - precision: 0.8177 - recall: 0.8177 - f1_metric: 0.7594 - val_loss: 0.7156 - val_accuracy: 0.6929 - val_precision: 0.6929 - val_recall: 0.6929 - val_f1_metric: 0.3467
# Epoch 4/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4604 - accuracy: 0.8334 - precision: 0.8334 - recall: 0.8334 - f1_metric: 0.7800 - val_loss: 0.7895 - val_accuracy: 0.4863 - val_precision: 0.4863 - val_recall: 0.4863 - val_f1_metric: 0.4600
# Epoch 5/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4465 - accuracy: 0.8334 - precision: 0.8334 - recall: 0.8334 - f1_metric: 0.7814 - val_loss: 0.7838 - val_accuracy: 0.7029 - val_precision: 0.7029 - val_recall: 0.7029 - val_f1_metric: 0.3775
#
# Training Client 3/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.5012 - accuracy: 0.8063 - precision: 0.8063 - recall: 0.8063 - f1_metric: 0.7496 - val_loss: 1.2160 - val_accuracy: 0.7054 - val_precision: 0.7054 - val_recall: 0.7054 - val_f1_metric: 0.0000e+00
# Epoch 2/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4917 - accuracy: 0.8069 - precision: 0.8069 - recall: 0.8069 - f1_metric: 0.7453 - val_loss: 0.6247 - val_accuracy: 0.6988 - val_precision: 0.6988 - val_recall: 0.6988 - val_f1_metric: 0.2298
# Epoch 3/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4874 - accuracy: 0.8129 - precision: 0.8129 - recall: 0.8129 - f1_metric: 0.7589 - val_loss: 0.6462 - val_accuracy: 0.6527 - val_precision: 0.6527 - val_recall: 0.6527 - val_f1_metric: 0.5313
# Epoch 4/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4813 - accuracy: 0.8105 - precision: 0.8105 - recall: 0.8105 - f1_metric: 0.7509 - val_loss: 0.7192 - val_accuracy: 0.6768 - val_precision: 0.6768 - val_recall: 0.6768 - val_f1_metric: 0.5469
# Epoch 5/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4576 - accuracy: 0.8274 - precision: 0.8274 - recall: 0.8274 - f1_metric: 0.7801 - val_loss: 0.8126 - val_accuracy: 0.7050 - val_precision: 0.7050 - val_recall: 0.7050 - val_f1_metric: 0.0056
#
# Training Client 4/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 63s 1s/step - loss: 0.5061 - accuracy: 0.8021 - precision: 0.8021 - recall: 0.8021 - f1_metric: 0.7370 - val_loss: 0.6616 - val_accuracy: 0.6851 - val_precision: 0.6851 - val_recall: 0.6851 - val_f1_metric: 0.5128
# Epoch 2/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4952 - accuracy: 0.7978 - precision: 0.7978 - recall: 0.7978 - f1_metric: 0.7418 - val_loss: 0.6466 - val_accuracy: 0.7029 - val_precision: 0.7029 - val_recall: 0.7029 - val_f1_metric: 0.3827
# Epoch 3/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4968 - accuracy: 0.8105 - precision: 0.8105 - recall: 0.8105 - f1_metric: 0.7564 - val_loss: 0.6580 - val_accuracy: 0.6929 - val_precision: 0.6929 - val_recall: 0.6929 - val_f1_metric: 0.4030
# Epoch 4/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4849 - accuracy: 0.8051 - precision: 0.8051 - recall: 0.8051 - f1_metric: 0.7441 - val_loss: 0.7981 - val_accuracy: 0.6763 - val_precision: 0.6763 - val_recall: 0.6763 - val_f1_metric: 0.4518
# Epoch 5/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4668 - accuracy: 0.8147 - precision: 0.8147 - recall: 0.8147 - f1_metric: 0.7584 - val_loss: 1.2129 - val_accuracy: 0.6959 - val_precision: 0.6959 - val_recall: 0.6959 - val_f1_metric: 0.1640
#
# Training Client 5/5
# train_generator:
# 32 1660
# Epoch 1/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.4936 - accuracy: 0.8120 - precision: 0.8120 - recall: 0.8120 - f1_metric: 0.7547 - val_loss: 0.6826 - val_accuracy: 0.6660 - val_precision: 0.6660 - val_recall: 0.6660 - val_f1_metric: 0.4476
# Epoch 2/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4651 - accuracy: 0.8295 - precision: 0.8295 - recall: 0.8295 - f1_metric: 0.7769 - val_loss: 0.6456 - val_accuracy: 0.7004 - val_precision: 0.7004 - val_recall: 0.7004 - val_f1_metric: 0.5060
# Epoch 3/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4800 - accuracy: 0.8084 - precision: 0.8084 - recall: 0.8084 - f1_metric: 0.7507 - val_loss: 0.6286 - val_accuracy: 0.6838 - val_precision: 0.6838 - val_recall: 0.6838 - val_f1_metric: 0.4442
# Epoch 4/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4565 - accuracy: 0.8313 - precision: 0.8313 - recall: 0.8313 - f1_metric: 0.7859 - val_loss: 0.7846 - val_accuracy: 0.6166 - val_precision: 0.6166 - val_recall: 0.6166 - val_f1_metric: 0.5295
# Epoch 5/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4381 - accuracy: 0.8325 - precision: 0.8325 - recall: 0.8325 - f1_metric: 0.7847 - val_loss: 0.7742 - val_accuracy: 0.6095 - val_precision: 0.6095 - val_recall: 0.6095 - val_f1_metric: 0.4336
#
# Evaluating global model:
# 76/76 [==============================] - 32s 421ms/step - loss: 0.6319 - accuracy: 0.7091 - precision: 0.7091 - recall: 0.7091 - f1_metric: 0.4366
# Test metrics: {'loss': 0.6318866014480591, 'accuracy': 0.7091286182403564, 'precision': 0.7091286182403564, 'recall': 0.7091286182403564, 'f1_metric': 0.4366152286529541}
#
# Round Training Metrics:
# loss: 0.4603
# accuracy: 0.8238
# precision: 0.8238
# recall: 0.8238
# f1_metric: 0.7681
# val_loss: 0.8584
# val_accuracy: 0.6647
# val_precision: 0.6647
# val_recall: 0.6647
# val_f1_metric: 0.2918
#
# Federated Learning Round 7/10
#
# Training Client 1/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.5152 - accuracy: 0.7821 - precision: 0.7821 - recall: 0.7821 - f1_metric: 0.7070 - val_loss: 0.8277 - val_accuracy: 0.6971 - val_precision: 0.6971 - val_recall: 0.6971 - val_f1_metric: 0.0920
# Epoch 2/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4938 - accuracy: 0.8002 - precision: 0.8002 - recall: 0.8002 - f1_metric: 0.7255 - val_loss: 0.7284 - val_accuracy: 0.6963 - val_precision: 0.6963 - val_recall: 0.6963 - val_f1_metric: 0.1549
# Epoch 3/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4779 - accuracy: 0.8081 - precision: 0.8081 - recall: 0.8081 - f1_metric: 0.7442 - val_loss: 0.7232 - val_accuracy: 0.6992 - val_precision: 0.6992 - val_recall: 0.6992 - val_f1_metric: 0.4054
# Epoch 4/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4631 - accuracy: 0.8189 - precision: 0.8189 - recall: 0.8189 - f1_metric: 0.7507 - val_loss: 0.6840 - val_accuracy: 0.7050 - val_precision: 0.7050 - val_recall: 0.7050 - val_f1_metric: 0.2125
# Epoch 5/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4809 - accuracy: 0.8196 - precision: 0.8196 - recall: 0.8196 - f1_metric: 0.7613 - val_loss: 0.7447 - val_accuracy: 0.6651 - val_precision: 0.6651 - val_recall: 0.6651 - val_f1_metric: 0.4019
#
# Training Client 2/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4726 - accuracy: 0.8214 - precision: 0.8214 - recall: 0.8214 - f1_metric: 0.7744 - val_loss: 0.8729 - val_accuracy: 0.5456 - val_precision: 0.5456 - val_recall: 0.5456 - val_f1_metric: 0.5114
# Epoch 2/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4425 - accuracy: 0.8328 - precision: 0.8328 - recall: 0.8328 - f1_metric: 0.7803 - val_loss: 0.7819 - val_accuracy: 0.7100 - val_precision: 0.7100 - val_recall: 0.7100 - val_f1_metric: 0.3242
# Epoch 3/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4345 - accuracy: 0.8352 - precision: 0.8352 - recall: 0.8352 - f1_metric: 0.7889 - val_loss: 0.8220 - val_accuracy: 0.6988 - val_precision: 0.6988 - val_recall: 0.6988 - val_f1_metric: 0.0737
# Epoch 4/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4510 - accuracy: 0.8352 - precision: 0.8352 - recall: 0.8352 - f1_metric: 0.7843 - val_loss: 0.8307 - val_accuracy: 0.7054 - val_precision: 0.7054 - val_recall: 0.7054 - val_f1_metric: 0.4668
# Epoch 5/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4308 - accuracy: 0.8346 - precision: 0.8346 - recall: 0.8346 - f1_metric: 0.7830 - val_loss: 0.8666 - val_accuracy: 0.6378 - val_precision: 0.6378 - val_recall: 0.6378 - val_f1_metric: 0.4155
#
# Training Client 3/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4745 - accuracy: 0.8135 - precision: 0.8135 - recall: 0.8135 - f1_metric: 0.7581 - val_loss: 0.6757 - val_accuracy: 0.7017 - val_precision: 0.7017 - val_recall: 0.7017 - val_f1_metric: 0.4726
# Epoch 2/5
# ...
# Epoch 4/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4166 - accuracy: 0.8380 - precision: 0.8380 - recall: 0.8380 - f1_metric: 0.7921 - val_loss: 0.6966 - val_accuracy: 0.6373 - val_precision: 0.6373 - val_recall: 0.6373 - val_f1_metric: 0.5034
# Epoch 5/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.3981 - accuracy: 0.8602 - precision: 0.8602 - recall: 0.8602 - f1_metric: 0.8215 - val_loss: 1.0435 - val_accuracy: 0.5506 - val_precision: 0.5506 - val_recall: 0.5506 - val_f1_metric: 0.5318
#
# Evaluating global model:
# 76/76 [==============================] - 32s 418ms/step - loss: 0.6408 - accuracy: 0.6838 - precision: 0.6838 - recall: 0.6838 - f1_metric: 0.5609
# Test metrics: {'loss': 0.64082932472229, 'accuracy': 0.683817446231842, 'precision': 0.683817446231842, 'recall': 0.683817446231842, 'f1_metric': 0.5608714818954468}
#
# Round Training Metrics:
# loss: 0.4206
# accuracy: 0.8418
# precision: 0.8418
# recall: 0.8418
# f1_metric: 0.7917
# val_loss: 0.8634
# val_accuracy: 0.6007
# val_precision: 0.6007
# val_recall: 0.6007
# val_f1_metric: 0.4733
#
# Federated Learning Round 9/10
#
# Training Client 1/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 64s 1s/step - loss: 0.4693 - accuracy: 0.8117 - precision: 0.8117 - recall: 0.8117 - f1_metric: 0.7453 - val_loss: 0.6693 - val_accuracy: 0.6975 - val_precision: 0.6975 - val_recall: 0.6975 - val_f1_metric: 0.4305
# Epoch 2/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4535 - accuracy: 0.8147 - precision: 0.8147 - recall: 0.8147 - f1_metric: 0.7423 - val_loss: 0.6647 - val_accuracy: 0.6975 - val_precision: 0.6975 - val_recall: 0.6975 - val_f1_metric: 0.3278
# Epoch 3/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4454 - accuracy: 0.8292 - precision: 0.8292 - recall: 0.8292 - f1_metric: 0.7678 - val_loss: 0.6779 - val_accuracy: 0.7041 - val_precision: 0.7041 - val_recall: 0.7041 - val_f1_metric: 0.0319
# Epoch 4/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4290 - accuracy: 0.8340 - precision: 0.8340 - recall: 0.8340 - f1_metric: 0.7799 - val_loss: 0.7330 - val_accuracy: 0.6689 - val_precision: 0.6689 - val_recall: 0.6689 - val_f1_metric: 0.4947
# Epoch 5/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4120 - accuracy: 0.8509 - precision: 0.8509 - recall: 0.8509 - f1_metric: 0.7966 - val_loss: 0.6837 - val_accuracy: 0.6959 - val_precision: 0.6959 - val_recall: 0.6959 - val_f1_metric: 0.3947
#
# Training Client 2/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 64s 1s/step - loss: 0.4401 - accuracy: 0.8256 - precision: 0.8256 - recall: 0.8256 - f1_metric: 0.7772 - val_loss: 0.6217 - val_accuracy: 0.7041 - val_precision: 0.7041 - val_recall: 0.7041 - val_f1_metric: 0.5072
# Epoch 2/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4128 - accuracy: 0.8437 - precision: 0.8437 - recall: 0.8437 - f1_metric: 0.7990 - val_loss: 0.8628 - val_accuracy: 0.6498 - val_precision: 0.6498 - val_recall: 0.6498 - val_f1_metric: 0.5357
# Epoch 3/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.3981 - accuracy: 0.8546 - precision: 0.8546 - recall: 0.8546 - f1_metric: 0.8138 - val_loss: 0.7385 - val_accuracy: 0.7145 - val_precision: 0.7145 - val_recall: 0.7145 - val_f1_metric: 0.4761
# Epoch 4/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.3844 - accuracy: 0.8533 - precision: 0.8533 - recall: 0.8533 - f1_metric: 0.8124 - val_loss: 0.9108 - val_accuracy: 0.6461 - val_precision: 0.6461 - val_recall: 0.6461 - val_f1_metric: 0.4577
# Epoch 5/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4014 - accuracy: 0.8533 - precision: 0.8533 - recall: 0.8533 - f1_metric: 0.8090 - val_loss: 0.8408 - val_accuracy: 0.6556 - val_precision: 0.6556 - val_recall: 0.6556 - val_f1_metric: 0.5591
#
# Training Client 3/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.4524 - accuracy: 0.8081 - precision: 0.8081 - recall: 0.8081 - f1_metric: 0.7565 - val_loss: 0.6369 - val_accuracy: 0.6963 - val_precision: 0.6963 - val_recall: 0.6963 - val_f1_metric: 0.3169
# Epoch 2/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4271 - accuracy: 0.8413 - precision: 0.8413 - recall: 0.8413 - f1_metric: 0.7948 - val_loss: 0.9389 - val_accuracy: 0.4979 - val_precision: 0.4979 - val_recall: 0.4979 - val_f1_metric: 0.4907
# Epoch 3/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4297 - accuracy: 0.8310 - precision: 0.8310 - recall: 0.8310 - f1_metric: 0.7801 - val_loss: 0.9491 - val_accuracy: 0.6884 - val_precision: 0.6884 - val_recall: 0.6884 - val_f1_metric: 0.4720
# Epoch 4/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4173 - accuracy: 0.8443 - precision: 0.8443 - recall: 0.8443 - f1_metric: 0.7998 - val_loss: 1.0300 - val_accuracy: 0.6963 - val_precision: 0.6963 - val_recall: 0.6963 - val_f1_metric: 0.3860
# Epoch 5/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4106 - accuracy: 0.8473 - precision: 0.8473 - recall: 0.8473 - f1_metric: 0.7954 - val_loss: 0.9712 - val_accuracy: 0.6896 - val_precision: 0.6896 - val_recall: 0.6896 - val_f1_metric: 0.3672
#
# Training Client 4/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 64s 1s/step - loss: 0.4551 - accuracy: 0.8250 - precision: 0.8250 - recall: 0.8250 - f1_metric: 0.7740 - val_loss: 0.8430 - val_accuracy: 0.5983 - val_precision: 0.5983 - val_recall: 0.5983 - val_f1_metric: 0.5143
# Epoch 2/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4370 - accuracy: 0.8256 - precision: 0.8256 - recall: 0.8256 - f1_metric: 0.7829 - val_loss: 0.8401 - val_accuracy: 0.7054 - val_precision: 0.7054 - val_recall: 0.7054 - val_f1_metric: 0.3362
# Epoch 3/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4398 - accuracy: 0.8298 - precision: 0.8298 - recall: 0.8298 - f1_metric: 0.7761 - val_loss: 0.6364 - val_accuracy: 0.7037 - val_precision: 0.7037 - val_recall: 0.7037 - val_f1_metric: 0.5259
# Epoch 4/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4160 - accuracy: 0.8377 - precision: 0.8377 - recall: 0.8377 - f1_metric: 0.7934 - val_loss: 0.7614 - val_accuracy: 0.6693 - val_precision: 0.6693 - val_recall: 0.6693 - val_f1_metric: 0.5282
# Epoch 5/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4110 - accuracy: 0.8527 - precision: 0.8527 - recall: 0.8527 - f1_metric: 0.8087 - val_loss: 0.7185 - val_accuracy: 0.6415 - val_precision: 0.6415 - val_recall: 0.6415 - val_f1_metric: 0.5412
#
# Training Client 5/5
# train_generator:
# 32 1660
# Epoch 1/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.4342 - accuracy: 0.8265 - precision: 0.8265 - recall: 0.8265 - f1_metric: 0.7781 - val_loss: 0.8367 - val_accuracy: 0.6892 - val_precision: 0.6892 - val_recall: 0.6892 - val_f1_metric: 0.5145
# Epoch 2/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.4056 - accuracy: 0.8452 - precision: 0.8452 - recall: 0.8452 - f1_metric: 0.8025 - val_loss: 0.8098 - val_accuracy: 0.6759 - val_precision: 0.6759 - val_recall: 0.6759 - val_f1_metric: 0.3278
# Epoch 3/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.3873 - accuracy: 0.8566 - precision: 0.8566 - recall: 0.8566 - f1_metric: 0.8196 - val_loss: 0.6487 - val_accuracy: 0.6929 - val_precision: 0.6929 - val_recall: 0.6929 - val_f1_metric: 0.4932
# Epoch 4/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.3849 - accuracy: 0.8627 - precision: 0.8627 - recall: 0.8627 - f1_metric: 0.8205 - val_loss: 0.8409 - val_accuracy: 0.7071 - val_precision: 0.7071 - val_recall: 0.7071 - val_f1_metric: 0.4571
# Epoch 5/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.3704 - accuracy: 0.8693 - precision: 0.8693 - recall: 0.8693 - f1_metric: 0.8373 - val_loss: 1.1586 - val_accuracy: 0.4842 - val_precision: 0.4842 - val_recall: 0.4842 - val_f1_metric: 0.5130
#
# Evaluating global model:
# 76/76 [==============================] - 32s 420ms/step - loss: 0.6861 - accuracy: 0.6846 - precision: 0.6846 - recall: 0.6846 - f1_metric: 0.5490
# Test metrics: {'loss': 0.6861445903778076, 'accuracy': 0.6846473217010498, 'precision': 0.6846473217010498, 'recall': 0.6846473217010498, 'f1_metric': 0.5489695072174072}
#
# Round Training Metrics:
# loss: 0.4011
# accuracy: 0.8547
# precision: 0.8547
# recall: 0.8547
# f1_metric: 0.8094
# val_loss: 0.8746
# val_accuracy: 0.6334
# val_precision: 0.6334
# val_recall: 0.6334
# val_f1_metric: 0.4750
#
# Federated Learning Round 10/10
#
# Training Client 1/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.4774 - accuracy: 0.8021 - precision: 0.8021 - recall: 0.8021 - f1_metric: 0.7452 - val_loss: 0.6451 - val_accuracy: 0.6967 - val_precision: 0.6967 - val_recall: 0.6967 - val_f1_metric: 0.3934
# Epoch 2/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4511 - accuracy: 0.8196 - precision: 0.8196 - recall: 0.8196 - f1_metric: 0.7600 - val_loss: 0.6211 - val_accuracy: 0.7046 - val_precision: 0.7046 - val_recall: 0.7046 - val_f1_metric: 0.4074
# Epoch 3/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4225 - accuracy: 0.8401 - precision: 0.8401 - recall: 0.8401 - f1_metric: 0.7840 - val_loss: 0.6462 - val_accuracy: 0.6946 - val_precision: 0.6946 - val_recall: 0.6946 - val_f1_metric: 0.3134
# Epoch 4/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4260 - accuracy: 0.8322 - precision: 0.8322 - recall: 0.8322 - f1_metric: 0.7737 - val_loss: 0.7642 - val_accuracy: 0.7162 - val_precision: 0.7162 - val_recall: 0.7162 - val_f1_metric: 0.4875
# Epoch 5/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4266 - accuracy: 0.8413 - precision: 0.8413 - recall: 0.8413 - f1_metric: 0.7828 - val_loss: 1.1753 - val_accuracy: 0.7046 - val_precision: 0.7046 - val_recall: 0.7046 - val_f1_metric: 0.0033
#
# Training Client 2/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4430 - accuracy: 0.8196 - precision: 0.8196 - recall: 0.8196 - f1_metric: 0.7733 - val_loss: 0.6864 - val_accuracy: 0.6394 - val_precision: 0.6394 - val_recall: 0.6394 - val_f1_metric: 0.5650
# Epoch 2/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4173 - accuracy: 0.8425 - precision: 0.8425 - recall: 0.8425 - f1_metric: 0.8033 - val_loss: 0.8003 - val_accuracy: 0.6934 - val_precision: 0.6934 - val_recall: 0.6934 - val_f1_metric: 0.2323
# Epoch 3/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4027 - accuracy: 0.8509 - precision: 0.8509 - recall: 0.8509 - f1_metric: 0.8037 - val_loss: 1.0165 - val_accuracy: 0.7058 - val_precision: 0.7058 - val_recall: 0.7058 - val_f1_metric: 0.0104
# Epoch 4/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.3740 - accuracy: 0.8630 - precision: 0.8630 - recall: 0.8630 - f1_metric: 0.8243 - val_loss: 1.0076 - val_accuracy: 0.7083 - val_precision: 0.7083 - val_recall: 0.7083 - val_f1_metric: 0.2463
# Epoch 5/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.3546 - accuracy: 0.8751 - precision: 0.8751 - recall: 0.8751 - f1_metric: 0.8344 - val_loss: 1.1215 - val_accuracy: 0.7008 - val_precision: 0.7008 - val_recall: 0.7008 - val_f1_metric: 0.1950
#
# Training Client 3/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.4419 - accuracy: 0.8250 - precision: 0.8250 - recall: 0.8250 - f1_metric: 0.7747 - val_loss: 0.7186 - val_accuracy: 0.6950 - val_precision: 0.6950 - val_recall: 0.6950 - val_f1_metric: 0.0780
# Epoch 2/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.4344 - accuracy: 0.8256 - precision: 0.8256 - recall: 0.8256 - f1_metric: 0.7743 - val_loss: 0.7089 - val_accuracy: 0.6905 - val_precision: 0.6905 - val_recall: 0.6905 - val_f1_metric: 0.1845
# Epoch 3/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.4220 - accuracy: 0.8383 - precision: 0.8383 - recall: 0.8383 - f1_metric: 0.7802 - val_loss: 0.6640 - val_accuracy: 0.7141 - val_precision: 0.7141 - val_recall: 0.7141 - val_f1_metric: 0.1078
# Epoch 4/5
# 52/52 [==============================] - 54s 1s/step - loss: 0.3889 - accuracy: 0.8702 - precision: 0.8702 - recall: 0.8702 - f1_metric: 0.8270 - val_loss: 0.8839 - val_accuracy: 0.6747 - val_precision: 0.6747 - val_recall: 0.6747 - val_f1_metric: 0.5208
# Epoch 5/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.3713 - accuracy: 0.8660 - precision: 0.8660 - recall: 0.8660 - f1_metric: 0.8234 - val_loss: 0.8006 - val_accuracy: 0.6979 - val_precision: 0.6979 - val_recall: 0.6979 - val_f1_metric: 0.2667
#
# Training Client 4/5
# train_generator:
# 32 1657
# Epoch 1/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.4599 - accuracy: 0.8159 - precision: 0.8159 - recall: 0.8159 - f1_metric: 0.7665 - val_loss: 0.8392 - val_accuracy: 0.4680 - val_precision: 0.4680 - val_recall: 0.4680 - val_f1_metric: 0.5004
# Epoch 2/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.4495 - accuracy: 0.8208 - precision: 0.8208 - recall: 0.8208 - f1_metric: 0.7694 - val_loss: 0.6298 - val_accuracy: 0.6722 - val_precision: 0.6722 - val_recall: 0.6722 - val_f1_metric: 0.5490
# Epoch 3/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.4010 - accuracy: 0.8467 - precision: 0.8467 - recall: 0.8467 - f1_metric: 0.8027 - val_loss: 0.7612 - val_accuracy: 0.7054 - val_precision: 0.7054 - val_recall: 0.7054 - val_f1_metric: 0.3669
# Epoch 4/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.3955 - accuracy: 0.8455 - precision: 0.8455 - recall: 0.8455 - f1_metric: 0.7993 - val_loss: 0.9311 - val_accuracy: 0.6842 - val_precision: 0.6842 - val_recall: 0.6842 - val_f1_metric: 0.3687
# Epoch 5/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.3858 - accuracy: 0.8564 - precision: 0.8564 - recall: 0.8564 - f1_metric: 0.8126 - val_loss: 1.1002 - val_accuracy: 0.5718 - val_precision: 0.5718 - val_recall: 0.5718 - val_f1_metric: 0.4896
#
# Training Client 5/5
# train_generator:
# 32 1660
# Epoch 1/5
# 52/52 [==============================] - 59s 1s/step - loss: 0.4236 - accuracy: 0.8446 - precision: 0.8446 - recall: 0.8446 - f1_metric: 0.8012 - val_loss: 0.8030 - val_accuracy: 0.6585 - val_precision: 0.6585 - val_recall: 0.6585 - val_f1_metric: 0.5301
# Epoch 2/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.3874 - accuracy: 0.8596 - precision: 0.8596 - recall: 0.8596 - f1_metric: 0.8223 - val_loss: 0.8169 - val_accuracy: 0.6369 - val_precision: 0.6369 - val_recall: 0.6369 - val_f1_metric: 0.5301
# Epoch 3/5
# 52/52 [==============================] - 56s 1s/step - loss: 0.3817 - accuracy: 0.8584 - precision: 0.8584 - recall: 0.8584 - f1_metric: 0.8200 - val_loss: 1.2387 - val_accuracy: 0.7054 - val_precision: 0.7054 - val_recall: 0.7054 - val_f1_metric: 0.0000e+00
# Epoch 4/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.3817 - accuracy: 0.8633 - precision: 0.8633 - recall: 0.8633 - f1_metric: 0.8246 - val_loss: 0.8435 - val_accuracy: 0.6336 - val_precision: 0.6336 - val_recall: 0.6336 - val_f1_metric: 0.5519
# Epoch 5/5
# 52/52 [==============================] - 55s 1s/step - loss: 0.3733 - accuracy: 0.8645 - precision: 0.8645 - recall: 0.8645 - f1_metric: 0.8273 - val_loss: 0.6626 - val_accuracy: 0.7095 - val_precision: 0.7095 - val_recall: 0.7095 - val_f1_metric: 0.4063
#
# Evaluating global model:
# 76/76 [==============================] - 32s 425ms/step - loss: 0.6457 - accuracy: 0.6942 - precision: 0.6942 - recall: 0.6942 - f1_metric: 0.5225
# Test metrics: {'loss': 0.6457248330116272, 'accuracy': 0.6941908597946167, 'precision': 0.6941908597946167, 'recall': 0.6941908597946167, 'f1_metric': 0.5225438475608826}
#
# Round Training Metrics:
# loss: 0.3823
# accuracy: 0.8606
# precision: 0.8606
# recall: 0.8606
# f1_metric: 0.8161
# val_loss: 0.9720
# val_accuracy: 0.6769
# val_precision: 0.6769
# val_recall: 0.6769
# val_f1_metric: 0.2722

# %%
test_directories = ["../data/federated_learning_data/AccAP/test", "../data/federated_learning_data/AccML/test", "../data/federated_learning_data/AccV/test"]

test_generator = CustomMultiInputDataGenerator(
    directories=test_directories,
    batch_size=32,
    image_size=img_shape,
    augment=False,
    num_classes=2,
    shuffle=False
)

# %%
from sklearn.metrics import f1_score, confusion_matrix
import numpy as np

def evaluate_model(model, generator):
    y_true = []
    y_pred = []
    
    # Loop over the generator to collect all predictions and true labels
    for i in range(len(generator)):
        images, batch_y_true = generator[i]
        
        # Get predictions from the model
        batch_predictions = model.predict(images, verbose=0)
        
        # Convert softmax output to binary class predictions
        batch_y_pred = np.argmax(batch_predictions, axis=1)
        
        # Convert ground truth if it's one-hot encoded
        batch_y_true = np.argmax(batch_y_true, axis=1)
        
        y_true.extend(batch_y_true.flatten())
        y_pred.extend(batch_y_pred.flatten())
    
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    
    # Calculate confusion matrix
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    
    # Total number of samples
    total_samples = len(y_true)
    
    # Convert counts to percentages
    tn_percent = (tn / total_samples) * 100
    fp_percent = (fp / total_samples) * 100
    fn_percent = (fn / total_samples) * 100
    tp_percent = (tp / total_samples) * 100
    
    # Calculate F1 metrics
    metrics = {
        'f1_micro': f1_score(y_true, y_pred, average='micro'),
        'f1_macro': f1_score(y_true, y_pred, average='macro'),
        'f1_weighted': f1_score(y_true, y_pred, average='weighted'),
        'f1_per_class': f1_score(y_true, y_pred, average=None),
        'true_positives_percentage': tp_percent,
        'true_negatives_percentage': tn_percent,
        'false_positives_percentage': fp_percent,
        'false_negatives_percentage': fn_percent
    }
    
    return metrics

results = evaluate_model(server.global_model, test_generator)

print(results)
# Out:
# {'f1_micro': 0.7984012789768186, 'f1_macro': 0.7778617883850252, 'f1_weighted': 0.8010902028240091, 'f1_per_class': array([0.71031473, 0.84540885]), 'true_positives_percentage': 55.12390087929656, 'true_negatives_percentage': 24.716227018385293, 'false_positives_percentage': 8.089528377298162, 'false_negatives_percentage': 12.070343725019985}
